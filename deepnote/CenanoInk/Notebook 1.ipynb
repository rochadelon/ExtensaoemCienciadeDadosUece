# %%
import pandas as pd
import requests
import os
import time
import re
from requests.exceptions import RequestException

# Substitua com sua chave de API do CORE
API_KEY = "XfCz461qd3BMH8NDt0GRWLjgUycbOs5k" # Mantenha sua chave aqui

# Caminho para sua planilha CSV de entrada
PLANILHA_ENTRADA = "/work/CenaNoink/planilha30_31_32(Sheet1).csv"

# Nome da coluna que contém os DOIs
COLUNA_DOI = "DOI"

# Arquivo CSV de saída para os resultados
ARQUIVO_SAIDA_RESULTADOS = "resultados_links_download_core_v5_rate_limit.csv"

# Configurações para o retry em caso de rate limit (erro 429)
MAX_RETRIES = 5
INITIAL_BACKOFF_SECONDS = 60 # Começa esperando 1 minuto se não houver Retry-After
MAX_BACKOFF_SECONDS = 300 # Espera máxima de 5 minutos

def obter_link_download_pdf_core(entity_id, entity_type="outputs"):
    """
    Constrói e retorna o link de download direto para o PDF de uma entidade (outputs ou works) da API CORE.
    """
    if not entity_id:
        # print(f"ID da entidade inválido para gerar link de download: {entity_id}") # Log menos verboso
        return None
    url_download = f"https://api.core.ac.uk/v3/{entity_type}/{entity_id}/pdf"
    # print(f"Link de download gerado para {entity_type} ID {entity_id}: {url_download}") # Log menos verboso
    return url_download

def buscar_entidade_por_doi(doi, entity_type="outputs"):
    """
    Busca uma entidade (outputs ou works) pelo DOI, com tratamento de rate limit (429).
    Retorna o ID da entidade, mensagem de erro (se houver), e lista de outputs para works.
    """
    query = f'doi:"{doi}"'
    url = f"https://api.core.ac.uk/v3/search/{entity_type}"
    headers = {"Authorization": f"Bearer {API_KEY}"}
    params = {"q": query, "limit": 1}
    
    current_retry = 0
    backoff_time = INITIAL_BACKOFF_SECONDS

    while current_retry < MAX_RETRIES:
        try:
            print(f"Buscando {entity_type} com DOI: {doi} (Tentativa {current_retry + 1}/{MAX_RETRIES})")
            response = requests.get(url, headers=headers, params=params, timeout=30) # Timeout aumentado
            response.raise_for_status() # Levanta erro para 4xx/5xx, exceto se tratado abaixo
            data = response.json()

            if data.get("results") and len(data["results"]) > 0:
                result = data["results"][0]
                entity_id = result.get("id")
                if not entity_id:
                    msg = f"ID não encontrado na resposta da API para {entity_type} DOI {doi}"
                    print(msg)
                    return None, msg, None
                
                print(f"{entity_type.capitalize()} ID encontrado: {entity_id} para DOI: {doi}")
                associated_outputs = result.get("outputs", []) if entity_type == "works" else None
                return str(entity_id), None, associated_outputs
            else:
                msg = f"Nenhum resultado encontrado para {entity_type} com DOI {doi}."
                print(msg)
                return None, msg, None

        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 429: # Too Many Requests
                print(f"Erro 429 (Too Many Requests) ao buscar {entity_type} para DOI {doi}.")
                retry_after_header = e.response.headers.get("Retry-After")
                wait_time = backoff_time

                if retry_after_header:
                    try:
                        wait_time = int(retry_after_header)
                        print(f"Cabeçalho Retry-After encontrado. Esperando por {wait_time} segundos.")
                    except ValueError:
                        print(f"Não foi possível converter Retry-After ('{retry_after_header}') para inteiro. Usando backoff padrão de {wait_time}s.")
                else:
                    print(f"Sem cabeçalho Retry-After. Usando backoff de {wait_time} segundos.")
                
                wait_time = min(wait_time, MAX_BACKOFF_SECONDS) # Garante que não espere demais
                
                if current_retry < MAX_RETRIES - 1:
                    print(f"Tentando novamente em {wait_time} segundos...")
                    time.sleep(wait_time)
                    current_retry += 1
                    # Para o próximo backoff, se não houver Retry-After, dobramos o tempo (limitado por MAX_BACKOFF_SECONDS)
                    backoff_time = min(backoff_time * 2, MAX_BACKOFF_SECONDS) 
                else:
                    msg = f"Máximo de retries ({MAX_RETRIES}) atingido para DOI {doi} após erro 429."
                    print(msg)
                    return None, msg, None
            
            elif e.response.status_code == 404: # Not Found específico da busca
                msg = f"404 Not Found (busca {entity_type}) para DOI {doi}."
                print(msg)
                return None, msg, None
            else: # Outros erros HTTP
                msg = f"Erro HTTP {e.response.status_code} ao buscar {entity_type} para DOI {doi}: {e}"
                print(msg)
                return None, msg, None
        
        except requests.exceptions.RequestException as e: # Erros de conexão, timeout, etc.
            msg = f"Erro de requisição ao buscar {entity_type} para DOI {doi} (Tentativa {current_retry + 1}): {e}"
            print(msg)
            if current_retry < MAX_RETRIES - 1:
                print(f"Tentando novamente em {backoff_time} segundos devido a erro de requisição...")
                time.sleep(backoff_time)
                current_retry += 1
                backoff_time = min(backoff_time * 2, MAX_BACKOFF_SECONDS)
            else:
                msg_final = f"Máximo de retries ({MAX_RETRIES}) atingido para DOI {doi} após erro de requisição."
                print(msg_final)
                return None, msg_final, None
        
        except Exception as e: # Outros erros (ex: JSONDecodeError)
            msg = f"Erro inesperado ao buscar {entity_type} para DOI {doi} (Tentativa {current_retry + 1}): {e}"
            print(msg)
            # Para erros de JSON, geralmente não adianta tentar novamente com a mesma requisição
            return None, msg, None
            
    return None, f"Falha ao buscar {entity_type} para DOI {doi} após {MAX_RETRIES} tentativas.", None


if __name__ == "__main__":
    try:
        df = None
        codificacoes = ['utf-8', 'latin-1', 'cp1252', 'iso-8859-1']
        for codificacao in codificacoes:
            try:
                df = pd.read_csv(PLANILHA_ENTRADA, encoding=codificacao)
                print(f"Arquivo CSV lido com sucesso usando a codificação: {codificacao}")
                break
            except UnicodeDecodeError:
                print(f"Falha ao ler CSV com codificação: {codificacao}. Tentando próxima...")
            except FileNotFoundError:
                print(f"ERRO: Arquivo de entrada não encontrado em: {PLANILHA_ENTRADA}")
                exit()

        if df is None:
            raise Exception(f"Não foi possível decodificar o arquivo CSV: {PLANILHA_ENTRADA} com as codificações testadas: {codificacoes}")

        resultados_finais = []

        if COLUNA_DOI not in df.columns:
            print(f"ERRO: Coluna DOI '{COLUNA_DOI}' não encontrada na planilha.")
            exit()

        print(f"\nIniciando processamento de DOIs da coluna: '{COLUNA_DOI}'")
        total_dois = len(df)
        for index, row in df.iterrows():
            doi = row[COLUNA_DOI]
            link_download_encontrado = None
            status_final = "Falha"
            motivo_falha_final = "DOI não processado"
            id_usado_para_link = None
            tipo_entidade_link = None
            
            # Inicializa os campos de tentativa
            core_id_output_tentado = None
            core_id_work_tentado = None
            core_id_output_do_work_tentado = None


            print(f"\n--- Processando DOI {index + 1}/{total_dois}: {doi} (Linha {index+2} da planilha) ---")

            if pd.isna(doi) or str(doi).strip() == "":
                print(f"DOI vazio ou NaN. Pulando.")
                motivo_falha_final = "DOI vazio ou NaN"
            else:
                doi_str = str(doi).strip()

                # Tentativa 1: Buscar e obter link de "Outputs"
                output_id, erro_busca_output, _ = buscar_entidade_por_doi(doi_str, "outputs")
                core_id_output_tentado = output_id # Registra a tentativa
                if output_id:
                    link_download_encontrado = obter_link_download_pdf_core(output_id, "outputs")
                    if link_download_encontrado:
                        status_final = "Sucesso"
                        motivo_falha_final = "Link obtido de Output direto"
                        id_usado_para_link = output_id
                        tipo_entidade_link = "outputs"
                else: # Se output_id é None
                    motivo_falha_final = f"Output não encontrado ou erro na busca: {erro_busca_output}"

                # Tentativa 2: Buscar e obter link de "Works" (se a tentativa 1 falhou)
                if not link_download_encontrado:
                    print(f"Fallback para 'Works' para DOI: {doi_str}")
                    work_id, erro_busca_work, associated_output_ids = buscar_entidade_por_doi(doi_str, "works")
                    core_id_work_tentado = work_id # Registra a tentativa
                    if work_id:
                        # Tentativa 2a: Obter link direto do Work
                        print(f"Tentando obter link do Work ID: {work_id}")
                        link_download_encontrado = obter_link_download_pdf_core(work_id, "works")
                        if link_download_encontrado:
                            status_final = "Sucesso"
                            motivo_falha_final = "Link obtido de Work direto"
                            id_usado_para_link = work_id
                            tipo_entidade_link = "works"
                        else:
                            motivo_falha_final = f"Falha ao gerar link do Work ID {work_id}."
                            
                            if associated_output_ids:
                                print(f"Work ID {work_id}. Tentando obter link de {len(associated_output_ids)} outputs associados.")
                                for assoc_output_id in associated_output_ids:
                                    core_id_output_do_work_tentado = assoc_output_id
                                    print(f"Tentando Output associado ID: {assoc_output_id} do Work ID: {work_id}")
                                    link_download_encontrado = obter_link_download_pdf_core(assoc_output_id, "outputs")
                                    if link_download_encontrado:
                                        status_final = "Sucesso"
                                        motivo_falha_final = f"Link obtido de Output ID {assoc_output_id} (associado ao Work ID {work_id})"
                                        id_usado_para_link = assoc_output_id
                                        tipo_entidade_link = "outputs (de work)"
                                        break 
                                if not link_download_encontrado:
                                    motivo_falha_final = f"Falha ao obter link de Work direto e de todos os {len(associated_output_ids)} outputs associados ao Work ID {work_id}."
                            elif not link_download_encontrado:
                                 motivo_falha_final += " Work não possui outputs associados listados para tentativa."
                    else: # Se work_id é None
                        # Combina as mensagens de erro se ambas as buscas falharam
                        if erro_busca_output and erro_busca_work:
                             motivo_falha_final = f"Output: {erro_busca_output}. Work: {erro_busca_work}."
                        elif erro_busca_work: # Se só a busca por work falhou (output já tinha sido tratada)
                             motivo_falha_final = f"Work não encontrado ou erro na busca: {erro_busca_work}"


            resultados_finais.append({
                'doi': doi, # Salva o DOI original da planilha
                'core_id_output_tentado': core_id_output_tentado,
                'core_id_work_tentado': core_id_work_tentado,
                'core_id_output_do_work_tentado': core_id_output_do_work_tentado if tipo_entidade_link == "outputs (de work)" else None,
                'id_usado_para_link': id_usado_para_link,
                'tipo_entidade_link': tipo_entidade_link,
                'status_link': status_final,
                'motivo_falha': motivo_falha_final if status_final == "Falha" else "",
                'link_download': link_download_encontrado
            })
            
            # Aumenta o delay base entre o processamento de cada DOI
            # 60 segundos / 10 reqs por minuto = 6 segundos por requisição.
            # Como podemos fazer mais de uma requisição por DOI, um valor maior é mais seguro.
            print("Aguardando 7 segundos antes do próximo DOI...")
            time.sleep(7) 

        if resultados_finais:
            resultados_df = pd.DataFrame(resultados_finais)
            colunas_esperadas = ['doi', 'core_id_output_tentado', 'core_id_work_tentado', 
                                 'core_id_output_do_work_tentado', 'id_usado_para_link',
                                 'tipo_entidade_link', 'status_link', 'motivo_falha', 'link_download']
            for col in colunas_esperadas:
                if col not in resultados_df.columns:
                    resultados_df[col] = None
            
            resultados_df = resultados_df[colunas_esperadas]
            resultados_df.to_csv(ARQUIVO_SAIDA_RESULTADOS, index=False, encoding='utf-8')
            print(f"\nResultados do processamento foram salvos em: {ARQUIVO_SAIDA_RESULTADOS}")
        else:
            print("\nNenhum DOI processado para salvar.")

    except FileNotFoundError:
        pass 
    except Exception as e:
        print(f"Ocorreu um erro geral e fatal no script: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 344/503: 10.1016/j.rcsar.2016.04.001 (Linha 345 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.rcsar.2016.04.001 (Tentativa 1/5)
# Outputs ID encontrado: 82483691 para DOI: 10.1016/j.rcsar.2016.04.001
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 345/503: 10.1590/1980-5373-MR-2017-0624 (Linha 346 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2017-0624 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1590/1980-5373-MR-2017-0624.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2017-0624 (Tentativa 2/5)
# Nenhum resultado encontrado para outputs com DOI 10.1590/1980-5373-MR-2017-0624.
# Fallback para 'Works' para DOI: 10.1590/1980-5373-MR-2017-0624
# Buscando works com DOI: 10.1590/1980-5373-MR-2017-0624 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1590/1980-5373-MR-2017-0624.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 346/503: 10.1155/2017/9814624 (Linha 347 da planilha) ---
# Buscando outputs com DOI: 10.1155/2017/9814624 (Tentativa 1/5)
# Outputs ID encontrado: 193685862 para DOI: 10.1155/2017/9814624
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 347/503: 10.1155/2017/3571454 (Linha 348 da planilha) ---
# Buscando outputs com DOI: 10.1155/2017/3571454 (Tentativa 1/5)
# Outputs ID encontrado: 194800498 para DOI: 10.1155/2017/3571454
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 348/503: 10.1155/2017/6039192 (Linha 349 da planilha) ---
# Buscando outputs com DOI: 10.1155/2017/6039192 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1155/2017/6039192.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1155/2017/6039192 (Tentativa 2/5)
# Outputs ID encontrado: 194244195 para DOI: 10.1155/2017/6039192
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 349/503: 10.2109/jcersj2.17040 (Linha 350 da planilha) ---
# Buscando outputs com DOI: 10.2109/jcersj2.17040 (Tentativa 1/5)
# Outputs ID encontrado: 340061375 para DOI: 10.2109/jcersj2.17040
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 350/503: 10.2147/NSA.S123447 (Linha 351 da planilha) ---
# Buscando outputs com DOI: 10.2147/NSA.S123447 (Tentativa 1/5)
# Outputs ID encontrado: 222365830 para DOI: 10.2147/NSA.S123447
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 351/503: 10.14356/kona.2017011 (Linha 352 da planilha) ---
# Buscando outputs com DOI: 10.14356/kona.2017011 (Tentativa 1/5)
# Outputs ID encontrado: 436556262 para DOI: 10.14356/kona.2017011
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 352/503: 10.1016/j.jeurceramsoc.2016.07.027 (Linha 353 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2016.07.027 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.jeurceramsoc.2016.07.027.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2016.07.027 (Tentativa 2/5)
# Outputs ID encontrado: 77231472 para DOI: 10.1016/j.jeurceramsoc.2016.07.027
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 353/503: 10.2298/PAC1701045N (Linha 354 da planilha) ---
# Buscando outputs com DOI: 10.2298/PAC1701045N (Tentativa 1/5)
# Outputs ID encontrado: 197923773 para DOI: 10.2298/PAC1701045N
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 354/503: 10.1007/s13204-017-0580-0 (Linha 355 da planilha) ---
# Buscando outputs com DOI: 10.1007/s13204-017-0580-0 (Tentativa 1/5)
# Outputs ID encontrado: 431861836 para DOI: 10.1007/s13204-017-0580-0
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 355/503: 10.1007/s10853-017-1365-2 (Linha 356 da planilha) ---
# Buscando outputs com DOI: 10.1007/s10853-017-1365-2 (Tentativa 1/5)
# Outputs ID encontrado: 96892984 para DOI: 10.1007/s10853-017-1365-2
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 356/503: 10.1007/s40843-017-9102-1 (Linha 357 da planilha) ---
# Buscando outputs com DOI: 10.1007/s40843-017-9102-1 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s40843-017-9102-1.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s40843-017-9102-1 (Tentativa 2/5)
# Outputs ID encontrado: 437437464 para DOI: 10.1007/s40843-017-9102-1
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 357/503: 10.1002/aic.15743 (Linha 358 da planilha) ---
# Buscando outputs com DOI: 10.1002/aic.15743 (Tentativa 1/5)
# Outputs ID encontrado: 273374013 para DOI: 10.1002/aic.15743
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 358/503: 10.1515/msp-2017-0066 (Linha 359 da planilha) ---
# Buscando outputs com DOI: 10.1515/msp-2017-0066 (Tentativa 1/5)
# Outputs ID encontrado: 209865370 para DOI: 10.1515/msp-2017-0066
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 359/503: 10.1111/jace.14971 (Linha 360 da planilha) ---
# Buscando outputs com DOI: 10.1111/jace.14971 (Tentativa 1/5)
# Outputs ID encontrado: 484150077 para DOI: 10.1111/jace.14971
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 360/503: 10.1016/j.ceramint.2017.05.170 (Linha 361 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.05.170 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.ceramint.2017.05.170.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.05.170 (Tentativa 2/5)
# Outputs ID encontrado: 228150194 para DOI: 10.1016/j.ceramint.2017.05.170
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 361/503: 10.1515/msp-2017-0058 (Linha 362 da planilha) ---
# Buscando outputs com DOI: 10.1515/msp-2017-0058 (Tentativa 1/5)
# Outputs ID encontrado: 282542446 para DOI: 10.1515/msp-2017-0058
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 362/503: 10.1002/adem.201700418 (Linha 363 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700418 (Tentativa 1/5)
# Outputs ID encontrado: 372440755 para DOI: 10.1002/adem.201700418
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 363/503: 10.1002/mawe.201700042 (Linha 364 da planilha) ---
# Buscando outputs com DOI: 10.1002/mawe.201700042 (Tentativa 1/5)
# Outputs ID encontrado: 240068710 para DOI: 10.1002/mawe.201700042
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 364/503: 10.1016/j.jeurceramsoc.2017.04.055 (Linha 365 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2017.04.055 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.jeurceramsoc.2017.04.055.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2017.04.055 (Tentativa 2/5)
# Outputs ID encontrado: 394292761 para DOI: 10.1016/j.jeurceramsoc.2017.04.055
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 365/503: 10.1016/j.jeurceramsoc.2017.05.016 (Linha 366 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2017.05.016 (Tentativa 1/5)
# Outputs ID encontrado: 234917064 para DOI: 10.1016/j.jeurceramsoc.2017.05.016
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 366/503: 10.1007/s12034-017-1451-8 (Linha 367 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1451-8 (Tentativa 1/5)
# Outputs ID encontrado: 338964959 para DOI: 10.1007/s12034-017-1451-8
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 367/503: 10.1007/s12034-017-1476-z (Linha 368 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1476-z (Tentativa 1/5)
# Outputs ID encontrado: 338976102 para DOI: 10.1007/s12034-017-1476-z
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 368/503: 10.1007/s40843-017-9097-8 (Linha 369 da planilha) ---
# Buscando outputs com DOI: 10.1007/s40843-017-9097-8 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s40843-017-9097-8.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s40843-017-9097-8 (Tentativa 2/5)
# Outputs ID encontrado: 437437467 para DOI: 10.1007/s40843-017-9097-8
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 369/503: 10.1074/jbc.M117.793992 (Linha 370 da planilha) ---
# Buscando outputs com DOI: 10.1074/jbc.M117.793992 (Tentativa 1/5)
# Nenhum resultado encontrado para outputs com DOI 10.1074/jbc.M117.793992.
# Fallback para 'Works' para DOI: 10.1074/jbc.M117.793992
# Buscando works com DOI: 10.1074/jbc.M117.793992 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1074/jbc.M117.793992.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 370/503: 10.1021/acsami.7b07927 (Linha 371 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b07927 (Tentativa 1/5)
# Outputs ID encontrado: 96741243 para DOI: 10.1021/acsami.7b07927
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 371/503: 10.1038/s41529-017-0012-3 (Linha 372 da planilha) ---
# Buscando outputs com DOI: 10.1038/s41529-017-0012-3 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1038/s41529-017-0012-3.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1038/s41529-017-0012-3 (Tentativa 2/5)
# Outputs ID encontrado: 201701797 para DOI: 10.1038/s41529-017-0012-3
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 372/503: 10.1016/j.matchemphys.2017.07.010 (Linha 373 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matchemphys.2017.07.010 (Tentativa 1/5)
# Outputs ID encontrado: 393509316 para DOI: 10.1016/j.matchemphys.2017.07.010
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 373/503: 10.1021/acsami.7b08198 (Linha 374 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b08198 (Tentativa 1/5)
# Outputs ID encontrado: 425164375 para DOI: 10.1021/acsami.7b08198
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 374/503: 10.1021/acsami.7b07519 (Linha 375 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b07519 (Tentativa 1/5)
# Outputs ID encontrado: 425164455 para DOI: 10.1021/acsami.7b07519
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 375/503: 10.1016/j.seppur.2017.05.029 (Linha 376 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.seppur.2017.05.029 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.seppur.2017.05.029.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.seppur.2017.05.029 (Tentativa 2/5)
# Outputs ID encontrado: 393641808 para DOI: 10.1016/j.seppur.2017.05.029
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 376/503: 10.1016/j.matdes.2017.05.017 (Linha 377 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matdes.2017.05.017 (Tentativa 1/5)
# Outputs ID encontrado: 111012013 para DOI: 10.1016/j.matdes.2017.05.017
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 377/503: 10.3390/c3030027 (Linha 378 da planilha) ---
# Buscando outputs com DOI: 10.3390/c3030027 (Tentativa 1/5)
# Outputs ID encontrado: 540090686 para DOI: 10.3390/c3030027
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 378/503: 10.1016/j.matchemphys.2017.06.011 (Linha 379 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matchemphys.2017.06.011 (Tentativa 1/5)
# Outputs ID encontrado: 83866415 para DOI: 10.1016/j.matchemphys.2017.06.011
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 379/503: 10.1016/j.jascer.2017.06.005 (Linha 380 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jascer.2017.06.005 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.jascer.2017.06.005.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.jascer.2017.06.005 (Tentativa 2/5)
# Outputs ID encontrado: 259285324 para DOI: 10.1016/j.jascer.2017.06.005
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 380/503: 10.1016/j.ceramint.2017.05.040 (Linha 381 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.05.040 (Tentativa 1/5)
# Outputs ID encontrado: 84080085 para DOI: 10.1016/j.ceramint.2017.05.040
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 381/503: 10.1002/adem.201700088 (Linha 382 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700088 (Tentativa 1/5)
# Outputs ID encontrado: 391770916 para DOI: 10.1002/adem.201700088
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 382/503: 10.1016/j.ijadhadh.2017.05.007 (Linha 383 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ijadhadh.2017.05.007 (Tentativa 1/5)
# Outputs ID encontrado: 393769651 para DOI: 10.1016/j.ijadhadh.2017.05.007
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 383/503: 10.1557/mrc.2017.44 (Linha 384 da planilha) ---
# Buscando outputs com DOI: 10.1557/mrc.2017.44 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1557/mrc.2017.44.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1557/mrc.2017.44 (Tentativa 2/5)
# Outputs ID encontrado: 352039528 para DOI: 10.1557/mrc.2017.44
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 384/503: 10.1590/1980-5373-MR-2017-0347 (Linha 385 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2017-0347 (Tentativa 1/5)
# Nenhum resultado encontrado para outputs com DOI 10.1590/1980-5373-MR-2017-0347.
# Fallback para 'Works' para DOI: 10.1590/1980-5373-MR-2017-0347
# Buscando works com DOI: 10.1590/1980-5373-MR-2017-0347 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1590/1980-5373-MR-2017-0347.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 385/503: 10.1002/adem.201700199 (Linha 386 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700199 (Tentativa 1/5)
# Outputs ID encontrado: 487651082 para DOI: 10.1002/adem.201700199
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 386/503: 10.5812/traumamon.36139 (Linha 387 da planilha) ---
# Buscando outputs com DOI: 10.5812/traumamon.36139 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.5812/traumamon.36139.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.5812/traumamon.36139 (Tentativa 2/5)
# Outputs ID encontrado: 433192085 para DOI: 10.5812/traumamon.36139
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 387/503: 10.1016/j.ijadhadh.2017.06.001 (Linha 388 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ijadhadh.2017.06.001 (Tentativa 1/5)
# Outputs ID encontrado: 85207986 para DOI: 10.1016/j.ijadhadh.2017.06.001
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 388/503: 10.1007/s10853-017-1193-4 (Linha 389 da planilha) ---
# Buscando outputs com DOI: 10.1007/s10853-017-1193-4 (Tentativa 1/5)
# Outputs ID encontrado: 396917372 para DOI: 10.1007/s10853-017-1193-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 389/503: 10.1590/1980-5373-MR-2016-0892 (Linha 390 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0892 (Tentativa 1/5)
# Nenhum resultado encontrado para outputs com DOI 10.1590/1980-5373-MR-2016-0892.
# Fallback para 'Works' para DOI: 10.1590/1980-5373-MR-2016-0892
# Buscando works com DOI: 10.1590/1980-5373-MR-2016-0892 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar works para DOI 10.1590/1980-5373-MR-2016-0892.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando works com DOI: 10.1590/1980-5373-MR-2016-0892 (Tentativa 2/5)
# Nenhum resultado encontrado para works com DOI 10.1590/1980-5373-MR-2016-0892.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 390/503: 10.1016/j.jsamd.2017.07.002 (Linha 391 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jsamd.2017.07.002 (Tentativa 1/5)
# Outputs ID encontrado: 207668994 para DOI: 10.1016/j.jsamd.2017.07.002
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 391/503: 10.1111/ijac.12747 (Linha 392 da planilha) ---
# Buscando outputs com DOI: 10.1111/ijac.12747 (Tentativa 1/5)
# Outputs ID encontrado: 161509057 para DOI: 10.1111/ijac.12747
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 392/503: 10.1007/s10853-017-1159-6 (Linha 393 da planilha) ---
# Buscando outputs com DOI: 10.1007/s10853-017-1159-6 (Tentativa 1/5)
# Outputs ID encontrado: 216299236 para DOI: 10.1007/s10853-017-1159-6
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 393/503: 10.1111/ijag.12267 (Linha 394 da planilha) ---
# Buscando outputs com DOI: 10.1111/ijag.12267 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1111/ijag.12267.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1111/ijag.12267 (Tentativa 2/5)
# Outputs ID encontrado: 429855684 para DOI: 10.1111/ijag.12267
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 394/503: 10.1002/adem.201700106 (Linha 395 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700106 (Tentativa 1/5)
# Outputs ID encontrado: 487630255 para DOI: 10.1002/adem.201700106
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 395/503: 10.1002/adem.201700170 (Linha 396 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700170 (Tentativa 1/5)
# Outputs ID encontrado: 372431031 para DOI: 10.1002/adem.201700170
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 396/503: 10.1016/j.jascer.2017.05.004 (Linha 397 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jascer.2017.05.004 (Tentativa 1/5)
# Outputs ID encontrado: 280842277 para DOI: 10.1016/j.jascer.2017.05.004
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 397/503: 10.3390/c3030022 (Linha 398 da planilha) ---
# Buscando outputs com DOI: 10.3390/c3030022 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.3390/c3030022.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.3390/c3030022 (Tentativa 2/5)
# Outputs ID encontrado: 540084569 para DOI: 10.3390/c3030022
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 398/503: 10.1016/j.ceramint.2017.04.095 (Linha 399 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.04.095 (Tentativa 1/5)
# Outputs ID encontrado: 394605332 para DOI: 10.1016/j.ceramint.2017.04.095
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 399/503: 10.1590/1980-5373-MR-2016-0557 (Linha 400 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0557 (Tentativa 1/5)
# Nenhum resultado encontrado para outputs com DOI 10.1590/1980-5373-MR-2016-0557.
# Fallback para 'Works' para DOI: 10.1590/1980-5373-MR-2016-0557
# Buscando works com DOI: 10.1590/1980-5373-MR-2016-0557 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1590/1980-5373-MR-2016-0557.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 400/503: 10.1002/adem.201700153 (Linha 401 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700153 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1002/adem.201700153.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1002/adem.201700153 (Tentativa 2/5)
# Outputs ID encontrado: 487630267 para DOI: 10.1002/adem.201700153
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 401/503: 10.1016/j.jascer.2017.07.001 (Linha 402 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jascer.2017.07.001 (Tentativa 1/5)
# Outputs ID encontrado: 87765660 para DOI: 10.1016/j.jascer.2017.07.001
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 402/503: 10.1007/s40145-017-0234-4 (Linha 403 da planilha) ---
# Buscando outputs com DOI: 10.1007/s40145-017-0234-4 (Tentativa 1/5)
# Outputs ID encontrado: 248533219 para DOI: 10.1007/s40145-017-0234-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 403/503: 10.1103/PhysRevMaterials.1.033804 (Linha 404 da planilha) ---
# Buscando outputs com DOI: 10.1103/PhysRevMaterials.1.033804 (Tentativa 1/5)
# Outputs ID encontrado: 83861834 para DOI: 10.1103/PhysRevMaterials.1.033804
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 404/503: 10.1016/j.ces.2017.05.002 (Linha 405 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ces.2017.05.002 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.ces.2017.05.002.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.ces.2017.05.002 (Tentativa 2/5)
# Outputs ID encontrado: 159302945 para DOI: 10.1016/j.ces.2017.05.002
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 405/503: 10.1021/acsami.7b06922 (Linha 406 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b06922 (Tentativa 1/5)
# Erro HTTP 500 ao buscar outputs para DOI 10.1021/acsami.7b06922: 500 Server Error: Internal Server Error for url: https://api.core.ac.uk/v3/search/outputs/?q=doi%3A%2210.1021%2Facsami.7b06922%22&limit=1
# Fallback para 'Works' para DOI: 10.1021/acsami.7b06922
# Buscando works com DOI: 10.1021/acsami.7b06922 (Tentativa 1/5)
# Erro HTTP 500 ao buscar works para DOI 10.1021/acsami.7b06922: 500 Server Error: Internal Server Error for url: https://api.core.ac.uk/v3/search/works/?q=doi%3A%2210.1021%2Facsami.7b06922%22&limit=1
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 406/503: 10.1038/s41529-017-0007-0 (Linha 407 da planilha) ---
# Buscando outputs com DOI: 10.1038/s41529-017-0007-0 (Tentativa 1/5)
# Outputs ID encontrado: 86557369 para DOI: 10.1038/s41529-017-0007-0
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 407/503: 10.1103/PhysRevMaterials.1.033402 (Linha 408 da planilha) ---
# Buscando outputs com DOI: 10.1103/PhysRevMaterials.1.033402 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1103/PhysRevMaterials.1.033402.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1103/PhysRevMaterials.1.033402 (Tentativa 2/5)
# Outputs ID encontrado: 630221758 para DOI: 10.1103/PhysRevMaterials.1.033402
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 408/503: 10.1021/acsami.7b06864 (Linha 409 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b06864 (Tentativa 1/5)
# Outputs ID encontrado: 425163847 para DOI: 10.1021/acsami.7b06864
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 409/503: 10.1016/j.ceramint.2017.04.123 (Linha 410 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.04.123 (Tentativa 1/5)
# Outputs ID encontrado: 394605337 para DOI: 10.1016/j.ceramint.2017.04.123
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 410/503: 10.1021/acsami.7b05326 (Linha 411 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b05326 (Tentativa 1/5)
# Outputs ID encontrado: 484121258 para DOI: 10.1021/acsami.7b05326
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 411/503: 10.1021/acsami.7b04950 (Linha 412 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b04950 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b04950.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b04950 (Tentativa 2/5)
# Outputs ID encontrado: 199365077 para DOI: 10.1021/acsami.7b04950
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 412/503: 10.1021/acsami.7b07339 (Linha 413 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b07339 (Tentativa 1/5)
# Outputs ID encontrado: 425163863 para DOI: 10.1021/acsami.7b07339
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 413/503: 10.1021/acsami.7b09197 (Linha 414 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b09197 (Tentativa 1/5)
# Outputs ID encontrado: 84146757 para DOI: 10.1021/acsami.7b09197
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 414/503: 10.1007/s11666-017-0592-z (Linha 415 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11666-017-0592-z (Tentativa 1/5)
# Outputs ID encontrado: 475602835 para DOI: 10.1007/s11666-017-0592-z
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 415/503: 10.1007/s11666-017-0595-9 (Linha 416 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11666-017-0595-9 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s11666-017-0595-9.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s11666-017-0595-9 (Tentativa 2/5)
# Outputs ID encontrado: 429945646 para DOI: 10.1007/s11666-017-0595-9
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 416/503: 10.1007/s13204-015-0491-x (Linha 417 da planilha) ---
# Buscando outputs com DOI: 10.1007/s13204-015-0491-x (Tentativa 1/5)
# Outputs ID encontrado: 81546618 para DOI: 10.1007/s13204-015-0491-x
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 417/503: 10.1007/s11666-017-0555-4 (Linha 418 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11666-017-0555-4 (Tentativa 1/5)
# Outputs ID encontrado: 262749875 para DOI: 10.1007/s11666-017-0555-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 418/503: 10.1049/mnl.2017.0109 (Linha 419 da planilha) ---
# Buscando outputs com DOI: 10.1049/mnl.2017.0109 (Tentativa 1/5)
# Outputs ID encontrado: 335461887 para DOI: 10.1049/mnl.2017.0109
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 419/503: 10.1002/adem.201700109 (Linha 420 da planilha) ---
# Buscando outputs com DOI: 10.1002/adem.201700109 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1002/adem.201700109.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1002/adem.201700109 (Tentativa 2/5)
# Outputs ID encontrado: 132277714 para DOI: 10.1002/adem.201700109
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 420/503: 10.1002/cjce.22800 (Linha 421 da planilha) ---
# Buscando outputs com DOI: 10.1002/cjce.22800 (Tentativa 1/5)
# Outputs ID encontrado: 614848974 para DOI: 10.1002/cjce.22800
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 421/503: 10.17586/2220-8054-2017-8-4-507-511 (Linha 422 da planilha) ---
# Buscando outputs com DOI: 10.17586/2220-8054-2017-8-4-507-511 (Tentativa 1/5)
# Outputs ID encontrado: 488731071 para DOI: 10.17586/2220-8054-2017-8-4-507-511
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 422/503: 10.1016/j.jeurceramsoc.2017.03.042 (Linha 423 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2017.03.042 (Tentativa 1/5)
# Outputs ID encontrado: 572201957 para DOI: 10.1016/j.jeurceramsoc.2017.03.042
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 423/503: 10.1007/s13204-017-0575-x (Linha 424 da planilha) ---
# Buscando outputs com DOI: 10.1007/s13204-017-0575-x (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s13204-017-0575-x.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s13204-017-0575-x (Tentativa 2/5)
# Outputs ID encontrado: 431861830 para DOI: 10.1007/s13204-017-0575-x
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 424/503: 10.1007/s10853-017-0777-3 (Linha 425 da planilha) ---
# Buscando outputs com DOI: 10.1007/s10853-017-0777-3 (Tentativa 1/5)
# Outputs ID encontrado: 266583905 para DOI: 10.1007/s10853-017-0777-3
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 425/503: 10.1016/j.jeurceramsoc.2017.03.065 (Linha 426 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jeurceramsoc.2017.03.065 (Tentativa 1/5)
# Outputs ID encontrado: 394292748 para DOI: 10.1016/j.jeurceramsoc.2017.03.065
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 426/503: 10.1021/acsami.7b05793 (Linha 427 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b05793 (Tentativa 1/5)
# Outputs ID encontrado: 128981540 para DOI: 10.1021/acsami.7b05793
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 427/503: 10.1021/acsami.7b02630 (Linha 428 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b02630 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b02630.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b02630 (Tentativa 2/5)
# Outputs ID encontrado: 572198930 para DOI: 10.1021/acsami.7b02630
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 428/503: 10.1080/14686996.2017.1344929 (Linha 429 da planilha) ---
# Buscando outputs com DOI: 10.1080/14686996.2017.1344929 (Tentativa 1/5)
# Outputs ID encontrado: 264906442 para DOI: 10.1080/14686996.2017.1344929
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 429/503: 10.1016/j.jnoncrysol.2017.04.022 (Linha 430 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jnoncrysol.2017.04.022 (Tentativa 1/5)
# Outputs ID encontrado: 83534159 para DOI: 10.1016/j.jnoncrysol.2017.04.022
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 430/503: 10.1016/j.matdes.2017.04.006 (Linha 431 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matdes.2017.04.006 (Tentativa 1/5)
# Outputs ID encontrado: 388408166 para DOI: 10.1016/j.matdes.2017.04.006
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 431/503: 10.1038/am.2017.107 (Linha 432 da planilha) ---
# Buscando outputs com DOI: 10.1038/am.2017.107 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1038/am.2017.107.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1038/am.2017.107 (Tentativa 2/5)
# Outputs ID encontrado: 430481084 para DOI: 10.1038/am.2017.107
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 432/503: 10.1021/acsami.7b03155 (Linha 433 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03155 (Tentativa 1/5)
# Outputs ID encontrado: 425163450 para DOI: 10.1021/acsami.7b03155
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 433/503: 10.1016/j.matdes.2017.03.067 (Linha 434 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matdes.2017.03.067 (Tentativa 1/5)
# Outputs ID encontrado: 81670724 para DOI: 10.1016/j.matdes.2017.03.067
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 434/503: 10.1016/j.ceramint.2017.02.123 (Linha 435 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.02.123 (Tentativa 1/5)
# Outputs ID encontrado: 81116668 para DOI: 10.1016/j.ceramint.2017.02.123
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 435/503: 10.1590/1980-5373-MR-2016-0686 (Linha 436 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0686 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1590/1980-5373-MR-2016-0686.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0686 (Tentativa 2/5)
# Outputs ID encontrado: 628688489 para DOI: 10.1590/1980-5373-MR-2016-0686
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 436/503: 10.1515/msp-2017-0054 (Linha 437 da planilha) ---
# Buscando outputs com DOI: 10.1515/msp-2017-0054 (Tentativa 1/5)
# Outputs ID encontrado: 87707678 para DOI: 10.1515/msp-2017-0054
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 437/503: 10.1177/0004563216685117 (Linha 438 da planilha) ---
# Buscando outputs com DOI: 10.1177/0004563216685117 (Tentativa 1/5)
# Outputs ID encontrado: 411423573 para DOI: 10.1177/0004563216685117
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 438/503: 10.1590/1980-5373-MR-2015-0611 (Linha 439 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2015-0611 (Tentativa 1/5)
# Outputs ID encontrado: 485756691 para DOI: 10.1590/1980-5373-MR-2015-0611
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 439/503: 10.1590/1980-5373-MR-2016-0647 (Linha 440 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0647 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1590/1980-5373-MR-2016-0647.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0647 (Tentativa 2/5)
# Outputs ID encontrado: 628654923 para DOI: 10.1590/1980-5373-MR-2016-0647
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 440/503: 10.1590/1980-5373-MR-2016-0757 (Linha 441 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0757 (Tentativa 1/5)
# Outputs ID encontrado: 322372776 para DOI: 10.1590/1980-5373-MR-2016-0757
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 441/503: 10.1590/1980-5373-MR-2017-0175 (Linha 442 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2017-0175 (Tentativa 1/5)
# Nenhum resultado encontrado para outputs com DOI 10.1590/1980-5373-MR-2017-0175.
# Fallback para 'Works' para DOI: 10.1590/1980-5373-MR-2017-0175
# Buscando works com DOI: 10.1590/1980-5373-MR-2017-0175 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1590/1980-5373-MR-2017-0175.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 442/503: 10.5152/jemcr.2016.1795 (Linha 443 da planilha) ---
# Buscando outputs com DOI: 10.5152/jemcr.2016.1795 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.5152/jemcr.2016.1795.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.5152/jemcr.2016.1795 (Tentativa 2/5)
# Outputs ID encontrado: 288332629 para DOI: 10.5152/jemcr.2016.1795
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 443/503: 10.1590/1980-5373-MR-2017-0180 (Linha 444 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2017-0180 (Tentativa 1/5)
# Outputs ID encontrado: 227072482 para DOI: 10.1590/1980-5373-MR-2017-0180
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 444/503: 10.4191/kcers.2017.54.4.05 (Linha 445 da planilha) ---
# Buscando outputs com DOI: 10.4191/kcers.2017.54.4.05 (Tentativa 1/5)
# Outputs ID encontrado: 342595700 para DOI: 10.4191/kcers.2017.54.4.05
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 445/503: 10.1557/jmr.2017.213 (Linha 446 da planilha) ---
# Buscando outputs com DOI: 10.1557/jmr.2017.213 (Tentativa 1/5)
# Outputs ID encontrado: 417726438 para DOI: 10.1557/jmr.2017.213
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 446/503: 10.1007/s10853-017-1039-0 (Linha 447 da planilha) ---
# Buscando outputs com DOI: 10.1007/s10853-017-1039-0 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s10853-017-1039-0.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s10853-017-1039-0 (Tentativa 2/5)
# Outputs ID encontrado: 81844766 para DOI: 10.1007/s10853-017-1039-0
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 447/503: 10.1590/1980-5373-MR-2016-0675 (Linha 448 da planilha) ---
# Buscando outputs com DOI: 10.1590/1980-5373-MR-2016-0675 (Tentativa 1/5)
# Outputs ID encontrado: 628673144 para DOI: 10.1590/1980-5373-MR-2016-0675
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 448/503: 10.1515/msp-2017-0041 (Linha 449 da planilha) ---
# Buscando outputs com DOI: 10.1515/msp-2017-0041 (Tentativa 1/5)
# Outputs ID encontrado: 87707695 para DOI: 10.1515/msp-2017-0041
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 449/503: 10.1021/acsami.7b05150 (Linha 450 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b05150 (Tentativa 1/5)
# Outputs ID encontrado: 287885626 para DOI: 10.1021/acsami.7b05150
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 450/503: 10.1021/acsami.7b04484 (Linha 451 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b04484 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b04484.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b04484 (Tentativa 2/5)
# Outputs ID encontrado: 132277823 para DOI: 10.1021/acsami.7b04484
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 451/503: 10.1080/14686996.2017.1336642 (Linha 452 da planilha) ---
# Buscando outputs com DOI: 10.1080/14686996.2017.1336642 (Tentativa 1/5)
# Outputs ID encontrado: 201613763 para DOI: 10.1080/14686996.2017.1336642
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 452/503: 10.1021/acsami.7b03435 (Linha 453 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03435 (Tentativa 1/5)
# Erro HTTP 500 ao buscar outputs para DOI 10.1021/acsami.7b03435: 500 Server Error: Internal Server Error for url: https://api.core.ac.uk/v3/search/outputs/?q=doi%3A%2210.1021%2Facsami.7b03435%22&limit=1
# Fallback para 'Works' para DOI: 10.1021/acsami.7b03435
# Buscando works com DOI: 10.1021/acsami.7b03435 (Tentativa 1/5)
# Works ID encontrado: 42964273 para DOI: 10.1021/acsami.7b03435
# Tentando obter link do Work ID: 42964273
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 453/503: 10.1021/acs.biochem.6b01192 (Linha 454 da planilha) ---
# Buscando outputs com DOI: 10.1021/acs.biochem.6b01192 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acs.biochem.6b01192.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acs.biochem.6b01192 (Tentativa 2/5)
# Outputs ID encontrado: 395869387 para DOI: 10.1021/acs.biochem.6b01192
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 454/503: 10.4253/wjge.v9.i6.282 (Linha 455 da planilha) ---
# Buscando outputs com DOI: 10.4253/wjge.v9.i6.282 (Tentativa 1/5)
# Outputs ID encontrado: 426642662 para DOI: 10.4253/wjge.v9.i6.282
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 455/503: 10.1016/j.ceramint.2017.02.062 (Linha 456 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ceramint.2017.02.062 (Tentativa 1/5)
# Outputs ID encontrado: 394605235 para DOI: 10.1016/j.ceramint.2017.02.062
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 456/503: 10.1186/s12876-017-0625-6 (Linha 457 da planilha) ---
# Buscando outputs com DOI: 10.1186/s12876-017-0625-6 (Tentativa 1/5)
# Outputs ID encontrado: 264448188 para DOI: 10.1186/s12876-017-0625-6
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 457/503: 10.1021/acsami.6b16425 (Linha 458 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.6b16425 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.6b16425.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.6b16425 (Tentativa 2/5)
# Outputs ID encontrado: 425163309 para DOI: 10.1021/acsami.6b16425
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 458/503: 10.1016/j.seppur.2017.02.049 (Linha 459 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.seppur.2017.02.049 (Tentativa 1/5)
# Outputs ID encontrado: 130355246 para DOI: 10.1016/j.seppur.2017.02.049
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 459/503: 10.1021/acsami.7b04840 (Linha 460 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b04840 (Tentativa 1/5)
# Outputs ID encontrado: 84840470 para DOI: 10.1021/acsami.7b04840
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 460/503: 10.1557/jmr.2017.204 (Linha 461 da planilha) ---
# Buscando outputs com DOI: 10.1557/jmr.2017.204 (Tentativa 1/5)
# Outputs ID encontrado: 207835540 para DOI: 10.1557/jmr.2017.204
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 461/503: 10.22226/2410-3535-2017-2-175-179 (Linha 462 da planilha) ---
# Buscando outputs com DOI: 10.22226/2410-3535-2017-2-175-179 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.22226/2410-3535-2017-2-175-179.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.22226/2410-3535-2017-2-175-179 (Tentativa 2/5)
# Outputs ID encontrado: 439259746 para DOI: 10.22226/2410-3535-2017-2-175-179
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 462/503: 10.1515/adms-2017-0008 (Linha 463 da planilha) ---
# Buscando outputs com DOI: 10.1515/adms-2017-0008 (Tentativa 1/5)
# Outputs ID encontrado: 489006306 para DOI: 10.1515/adms-2017-0008
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 463/503: 10.1515/adms-2017-0007 (Linha 464 da planilha) ---
# Buscando outputs com DOI: 10.1515/adms-2017-0007 (Tentativa 1/5)
# Outputs ID encontrado: 338924731 para DOI: 10.1515/adms-2017-0007
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 464/503: 10.1007/s11666-017-0563-4 (Linha 465 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11666-017-0563-4 (Tentativa 1/5)
# Outputs ID encontrado: 485391722 para DOI: 10.1007/s11666-017-0563-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 465/503: 10.1016/j.jsamd.2017.04.002 (Linha 466 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.jsamd.2017.04.002 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1016/j.jsamd.2017.04.002.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1016/j.jsamd.2017.04.002 (Tentativa 2/5)
# Outputs ID encontrado: 254169476 para DOI: 10.1016/j.jsamd.2017.04.002
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 466/503: 10.1016/j.tjog.2017.04.025 (Linha 467 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.tjog.2017.04.025 (Tentativa 1/5)
# Outputs ID encontrado: 258193173 para DOI: 10.1016/j.tjog.2017.04.025
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 467/503: 10.1007/s12034-017-1398-9 (Linha 468 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1398-9 (Tentativa 1/5)
# Outputs ID encontrado: 422981308 para DOI: 10.1007/s12034-017-1398-9
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 468/503: 10.1111/febs.14073 (Linha 469 da planilha) ---
# Buscando outputs com DOI: 10.1111/febs.14073 (Tentativa 1/5)
# Outputs ID encontrado: 416695180 para DOI: 10.1111/febs.14073
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 469/503: 10.2979/reseafrilite.48.2.11 (Linha 470 da planilha) ---
# Buscando outputs com DOI: 10.2979/reseafrilite.48.2.11 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.2979/reseafrilite.48.2.11.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.2979/reseafrilite.48.2.11 (Tentativa 2/5)
# Outputs ID encontrado: 83960185 para DOI: 10.2979/reseafrilite.48.2.11
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 470/503: 10.1016/j.matchemphys.2017.02.047 (Linha 471 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matchemphys.2017.02.047 (Tentativa 1/5)
# Outputs ID encontrado: 393509265 para DOI: 10.1016/j.matchemphys.2017.02.047
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 471/503: 10.1111/anae.13786 (Linha 472 da planilha) ---
# Buscando outputs com DOI: 10.1111/anae.13786 (Tentativa 1/5)
# Outputs ID encontrado: 77022333 para DOI: 10.1111/anae.13786
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 472/503: 10.1007/s12034-017-1399-8 (Linha 473 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1399-8 (Tentativa 1/5)
# Outputs ID encontrado: 158348315 para DOI: 10.1007/s12034-017-1399-8
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 473/503: 10.1007/s12034-017-1390-4 (Linha 474 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1390-4 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s12034-017-1390-4.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s12034-017-1390-4 (Tentativa 2/5)
# Outputs ID encontrado: 340073642 para DOI: 10.1007/s12034-017-1390-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 474/503: 10.1007/s12034-017-1396-y (Linha 475 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1396-y (Tentativa 1/5)
# Outputs ID encontrado: 628636506 para DOI: 10.1007/s12034-017-1396-y
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 475/503: 10.1007/s12034-017-1392-2 (Linha 476 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1392-2 (Tentativa 1/5)
# Outputs ID encontrado: 422981307 para DOI: 10.1007/s12034-017-1392-2
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 476/503: 10.1007/s11666-017-0565-2 (Linha 477 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11666-017-0565-2 (Tentativa 1/5)
# Outputs ID encontrado: 340047062 para DOI: 10.1007/s11666-017-0565-2
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 477/503: 10.1515/adms-2017-0010 (Linha 478 da planilha) ---
# Buscando outputs com DOI: 10.1515/adms-2017-0010 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1515/adms-2017-0010.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1515/adms-2017-0010 (Tentativa 2/5)
# Outputs ID encontrado: 338924733 para DOI: 10.1515/adms-2017-0010
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 478/503: 10.1016/j.ijadhadh.2017.03.011 (Linha 479 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.ijadhadh.2017.03.011 (Tentativa 1/5)
# Outputs ID encontrado: 83534143 para DOI: 10.1016/j.ijadhadh.2017.03.011
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 479/503: 10.1007/s12034-017-1402-4 (Linha 480 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1402-4 (Tentativa 1/5)
# Outputs ID encontrado: 340073730 para DOI: 10.1007/s12034-017-1402-4
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 480/503: 10.1016/j.apmt.2017.01.005 (Linha 481 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.apmt.2017.01.005 (Tentativa 1/5)
# Outputs ID encontrado: 346474793 para DOI: 10.1016/j.apmt.2017.01.005
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 481/503: 10.1007/s12034-017-1388-y (Linha 482 da planilha) ---
# Buscando outputs com DOI: 10.1007/s12034-017-1388-y (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1007/s12034-017-1388-y.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1007/s12034-017-1388-y (Tentativa 2/5)
# Outputs ID encontrado: 422981298 para DOI: 10.1007/s12034-017-1388-y
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 482/503: 10.1016/j.apmt.2017.01.008 (Linha 483 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.apmt.2017.01.008 (Tentativa 1/5)
# Outputs ID encontrado: 424013005 para DOI: 10.1016/j.apmt.2017.01.008
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 483/503: 10.1021/acsami.7b01615 (Linha 484 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b01615 (Tentativa 1/5)
# Outputs ID encontrado: 512141527 para DOI: 10.1021/acsami.7b01615
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 484/503: 10.1016/j.seppur.2017.02.037 (Linha 485 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.seppur.2017.02.037 (Tentativa 1/5)
# Outputs ID encontrado: 84044559 para DOI: 10.1016/j.seppur.2017.02.037
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 485/503: 10.1074/jbc.M117.786012 (Linha 486 da planilha) ---
# Buscando outputs com DOI: 10.1074/jbc.M117.786012 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1074/jbc.M117.786012.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1074/jbc.M117.786012 (Tentativa 2/5)
# Nenhum resultado encontrado para outputs com DOI 10.1074/jbc.M117.786012.
# Fallback para 'Works' para DOI: 10.1074/jbc.M117.786012
# Buscando works com DOI: 10.1074/jbc.M117.786012 (Tentativa 1/5)
# Nenhum resultado encontrado para works com DOI 10.1074/jbc.M117.786012.
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 486/503: 10.1021/acsami.7b03288 (Linha 487 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03288 (Tentativa 1/5)
# Outputs ID encontrado: 425163010 para DOI: 10.1021/acsami.7b03288
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 487/503: 10.1074/jbc.M117.781880 (Linha 488 da planilha) ---
# Buscando outputs com DOI: 10.1074/jbc.M117.781880 (Tentativa 1/5)
# Outputs ID encontrado: 84057913 para DOI: 10.1074/jbc.M117.781880
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 488/503: 10.1021/acsami.7b02022 (Linha 489 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b02022 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b02022.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b02022 (Tentativa 2/5)
# Outputs ID encontrado: 83631142 para DOI: 10.1021/acsami.7b02022
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 489/503: 10.1021/acsami.7b03451 (Linha 490 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03451 (Tentativa 1/5)
# Outputs ID encontrado: 425162918 para DOI: 10.1021/acsami.7b03451
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 490/503: 10.1021/acsami.7b03168 (Linha 491 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03168 (Tentativa 1/5)
# Outputs ID encontrado: 87080667 para DOI: 10.1021/acsami.7b03168
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 491/503: 10.1021/acsami.7b03402 (Linha 492 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b03402 (Tentativa 1/5)
# Outputs ID encontrado: 425162896 para DOI: 10.1021/acsami.7b03402
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 492/503: 10.1021/acsami.7b01408 (Linha 493 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b01408 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b01408.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b01408 (Tentativa 2/5)
# Outputs ID encontrado: 340035614 para DOI: 10.1021/acsami.7b01408
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 493/503: 10.1021/acsami.7b00217 (Linha 494 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b00217 (Tentativa 1/5)
# Outputs ID encontrado: 81582977 para DOI: 10.1021/acsami.7b00217
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 494/503: 10.1021/acsami.7b00595 (Linha 495 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b00595 (Tentativa 1/5)
# Outputs ID encontrado: 425162697 para DOI: 10.1021/acsami.7b00595
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 495/503: 10.1021/acsami.7b01733 (Linha 496 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b01733 (Tentativa 1/5)
# Outputs ID encontrado: 340035466 para DOI: 10.1021/acsami.7b01733
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 496/503: 10.1021/acsami.7b00268 (Linha 497 da planilha) ---
# Buscando outputs com DOI: 10.1021/acsami.7b00268 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1021/acsami.7b00268.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1021/acsami.7b00268 (Tentativa 2/5)
# Outputs ID encontrado: 591732771 para DOI: 10.1021/acsami.7b00268
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 497/503: 10.3103/S1063457617030042 (Linha 498 da planilha) ---
# Buscando outputs com DOI: 10.3103/S1063457617030042 (Tentativa 1/5)
# Outputs ID encontrado: 324257862 para DOI: 10.3103/S1063457617030042
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 498/503: 10.1016/j.bsecv.2017.05.001 (Linha 499 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.bsecv.2017.05.001 (Tentativa 1/5)
# Outputs ID encontrado: 88043589 para DOI: 10.1016/j.bsecv.2017.05.001
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 499/503: 10.1016/j.matchemphys.2016.12.063 (Linha 500 da planilha) ---
# Buscando outputs com DOI: 10.1016/j.matchemphys.2016.12.063 (Tentativa 1/5)
# Outputs ID encontrado: 143696662 para DOI: 10.1016/j.matchemphys.2016.12.063
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 500/503: 10.1111/jace.14881 (Linha 501 da planilha) ---
# Buscando outputs com DOI: 10.1111/jace.14881 (Tentativa 1/5)
# Erro 429 (Too Many Requests) ao buscar outputs para DOI 10.1111/jace.14881.
# Sem cabeçalho Retry-After. Usando backoff de 60 segundos.
# Tentando novamente em 60 segundos...
# Buscando outputs com DOI: 10.1111/jace.14881 (Tentativa 2/5)
# Outputs ID encontrado: 195369987 para DOI: 10.1111/jace.14881
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 501/503: 10.1002/ceat.201600580 (Linha 502 da planilha) ---
# Buscando outputs com DOI: 10.1002/ceat.201600580 (Tentativa 1/5)
# Outputs ID encontrado: 153442046 para DOI: 10.1002/ceat.201600580
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 502/503: 10.1007/s11665-017-2662-2 (Linha 503 da planilha) ---
# Buscando outputs com DOI: 10.1007/s11665-017-2662-2 (Tentativa 1/5)
# Outputs ID encontrado: 413710919 para DOI: 10.1007/s11665-017-2662-2
# Aguardando 7 segundos antes do próximo DOI...
#
# --- Processando DOI 503/503: 10.1088/2053-1591/aa6c15 (Linha 504 da planilha) ---
# Buscando outputs com DOI: 10.1088/2053-1591/aa6c15 (Tentativa 1/5)
# Outputs ID encontrado: 436478695 para DOI: 10.1088/2053-1591/aa6c15
# Aguardando 7 segundos antes do próximo DOI...
#
# Resultados do processamento foram salvos em: resultados_links_download_core_v5_rate_limit.csv

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d35fdc8b-8543-45dc-ae25-3ba609dd01b9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
